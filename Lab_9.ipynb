# %% [markdown]
# <a href="https://colab.research.google.com/github/Naitik18-prog/ALGO-LAB/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
import heapq

def dijkstra(graph, start):
    pq = [(0, start)]
    distances = {node: float('inf') for node in graph}
    distances[start] = 0
    previous = {node: None for node in graph}

    while pq:
        current_distance, current_node = heapq.heappop(pq)

        if current_distance > distances[current_node]:
            continue

        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                previous[neighbor] = current_node
                heapq.heappush(pq, (distance, neighbor))

    return distances, previous
def shortest_path(previous, start, target):
    path = []
    node = target
    while node is not None:
        path.insert(0, node)
        node = previous[node]
    return path if path and path[0] == start else []

# %%
graph = {}
n = int(input("Enter number of nodes: "))
for i in range(n):
    node = input(f"Enter node {i+1} name: ").strip().upper()
    graph[node] = {}

m = int(input("Enter number of edges: "))
for i in range(m):
    u = input("Enter start node: ").strip().upper()
    v = input("Enter end node: ").strip().upper()
    w = int(input("Enter weight: "))
    graph[u][v] = w
    graph[v][u] = w   # if undirected

source = input("Enter source node: ").strip().upper()

# --- Run Dijkstra ---
distances, previous = dijkstra(graph, source)

print(f"\nShortest paths from {source}:")
for node in graph:
    path = shortest_path(previous, source, node)
    if distances[node] == float('inf'):
        print(f"{node}: No path")
    else:
        print(f"{node}: Path {' -> '.join(path)}, Distance = {distances[node]}")
# Out:
# Enter number of nodes: 5
# Enter node 1 name: A
# Enter node 2 name: B
# Enter node 3 name: C
# Enter node 4 name: D
# Enter node 5 name: E
# Enter number of edges: 5
# Enter start node: A
# Enter end node: B
# Enter weight: 5
# Enter start node: B
# Enter end node: C
# Enter weight: 4
# Enter start node: C
# Enter end node: D
# Enter weight: 3
# Enter start node: D
# Enter end node: E
# Enter weight: 2
# Enter start node: E
# Enter end node: A
# Enter weight: 1
# Enter source node: A
#
# Shortest paths from A:
# A: Path A, Distance = 0
# B: Path A -> B, Distance = 5
# C: Path A -> E -> D -> C, Distance = 6
# D: Path A -> E -> D, Distance = 3
# E: Path A -> E, Distance = 1

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
